# %% [markdown]
# <a href="https://colab.research.google.com/github/lclark7/stylometry-of-baen-books/blob/main/Stylometric_Comparison_of_Baen_Books_Science_Fiction_Authors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stylometric Comparison of Baen Books Science Fiction Authors
#
# This is a Colab Notebook to work through the examples for my Stylometric Comparison of Baen Books Science Fiction Authors project. This notebook will contain step-by-step instructions on how I conducted this comparison using Plotly to graph the results. A full explanation of this project can be found on my WordPress site, and all of this information can also be found on my GitHub.

# %% [markdown]
# First, we need to install Plotly. This is done by prompting Plotly to install.

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)

# %% [markdown]
# Now we need to import some modules so Python can read the files I will be using in this dataset. We are also going to install some modules related to Plotly so we do not have to do so later.

# %%
import pandas as pd 
import numpy as np 
import plotly.graph_objects as go 
import plotly.express as px 
import glob
import os
from textblob import TextBlob
import nltk
nltk.download('punkt')
import plotly.io as pio
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# Now it is time to upload the corpus or dataset we will be using. The dataset being used for this computational analysis came from Baen Books' Free Online Library. Each of these books were downloaded in EPUB format and then converted to TXT. These files were put into a compressed ZIP file to reduce space when being uploaded to the notebook session. The only thing the next line of code will be doing is unzipping the compressed file for use.
#
# *Note: This corpus does not include every book from Baen Books Free Library. Titles with more than two authors were excluded to reduce confusion and to save time when conducting this analysis. As of April 2022, there are 75 free ebooks available from Baen Books. This dataset is only comprised of 49 ebooks, some of which are repeating due to more than one author from the dataset working on them.

# %%
# !unzip "/content/BaenBooksCorpus2.zip"
# Out:
# Archive:  /content/BaenBooksCorpus2.zip
#    creating: BaenBooksCorpus2/Andre_Norton/
#   inflating: BaenBooksCorpus2/Andre_Norton/Star_Soldiers.txt
#   inflating: BaenBooksCorpus2/Andre_Norton/Time_Traders.txt
#    creating: BaenBooksCorpus2/Charles_Gannon/
#   inflating: BaenBooksCorpus2/Charles_Gannon/Fire_with_Fire.txt
#    creating: BaenBooksCorpus2/Dave_Freer/
#   inflating: BaenBooksCorpus2/Dave_Freer/The_Forlorn.txt
#    creating: BaenBooksCorpus2/David_Drake/
#   inflating: BaenBooksCorpus2/David_Drake/In_the_Heart_of_Darkness.txt
#   inflating: BaenBooksCorpus2/David_Drake/Northworld_Trilogy.txt
#   inflating: BaenBooksCorpus2/David_Drake/Old_Nathan.txt
#   inflating: BaenBooksCorpus2/David_Drake/Redliners.txt
#   inflating: BaenBooksCorpus2/David_Drake/Seas_of_Venus.txt
#   inflating: BaenBooksCorpus2/David_Drake/Starliner.txt
#   inflating: BaenBooksCorpus2/David_Drake/The_Sea_Hag.txt
#   inflating: BaenBooksCorpus2/David_Drake/The_Tank_Lords.txt
#   inflating: BaenBooksCorpus2/David_Drake/With_the_Lightnings.txt
#    creating: BaenBooksCorpus2/David_Weber/
#   inflating: BaenBooksCorpus2/David_Weber/Oath_of_Swords.txt
#   inflating: BaenBooksCorpus2/David_Weber/On_Basilisk_Station.txt
#   inflating: BaenBooksCorpus2/David_Weber/The_Honor_of_the_Queen.txt
#    creating: BaenBooksCorpus2/Ellen_Guon/
#   inflating: BaenBooksCorpus2/Ellen_Guon/Bedlam_Boyz.txt
#    creating: BaenBooksCorpus2/Eric_Flint/
#   inflating: BaenBooksCorpus2/Eric_Flint/1632.txt
#   inflating: BaenBooksCorpus2/Eric_Flint/Boundary.txt
#   inflating: BaenBooksCorpus2/Eric_Flint/Images_From_the_Grantville_Gazette.txt
#   inflating: BaenBooksCorpus2/Eric_Flint/In_the_Heart_of_Darkness.txt
#   inflating: BaenBooksCorpus2/Eric_Flint/Prime_Palaver.txt
#   inflating: BaenBooksCorpus2/Eric_Flint/The_Course_of_Empire.txt
#   inflating: BaenBooksCorpus2/Eric_Flint/The_Creatures_of_Man.txt
#   inflating: BaenBooksCorpus2/Eric_Flint/The_Philosophical_Strangler.txt
#    creating: BaenBooksCorpus2/John_Joseph_Adams/
#   inflating: BaenBooksCorpus2/John_Joseph_Adams/Selections_from_Brave_New_Worlds_ Dystopian_Stories.txt
#   inflating: BaenBooksCorpus2/John_Joseph_Adams/Selections_from_By_Blood_We_Live.txt
#   inflating: BaenBooksCorpus2/John_Joseph_Adams/Selections_from_The_Improbable_Adventures_of_Sherlock_Holmes.txt
#   inflating: BaenBooksCorpus2/John_Joseph_Adams/Selections_From_The_Living_Dead_2.txt
#    creating: BaenBooksCorpus2/John_Ringo/
#   inflating: BaenBooksCorpus2/John_Ringo/A_Hymn_Before_Battle.txt
#   inflating: BaenBooksCorpus2/John_Ringo/Emerald_Sea.txt
#   inflating: BaenBooksCorpus2/John_Ringo/Gust_Front.txt
#   inflating: BaenBooksCorpus2/John_Ringo/There_Will_Be_Dragons.txt
#    creating: BaenBooksCorpus2/Larry_Correia/
#   inflating: BaenBooksCorpus2/Larry_Correia/Monster_Hunter_International.txt
#    creating: BaenBooksCorpus2/Marc_Stiegler/
#   inflating: BaenBooksCorpus2/Marc_Stiegler/EarthWeb.txt
#    creating: BaenBooksCorpus2/Michael_Williamson/
#   inflating: BaenBooksCorpus2/Michael_Williamson/Freehold.txt
#    creating: BaenBooksCorpus2/Rosemary_Edgehill/
#   inflating: BaenBooksCorpus2/Rosemary_Edgehill/The_Warslayer.txt
#    creating: BaenBooksCorpus2/Ryk_Spoor/
#   inflating: BaenBooksCorpus2/Ryk_Spoor/Boundary.txt
#   inflating: BaenBooksCorpus2/Ryk_Spoor/Digital_Knight.txt
#   inflating: BaenBooksCorpus2/Ryk_Spoor/Grand_Central_Arena.txt
#   inflating: BaenBooksCorpus2/Ryk_Spoor/Phoenix_Rising.txt
#    creating: BaenBooksCorpus2/Scott_Gier/
#   inflating: BaenBooksCorpus2/Scott_Gier/Genellan-Planetfall.txt
#    creating: BaenBooksCorpus2/Sharon_Lee_and_Steve_Miller/
#   inflating: BaenBooksCorpus2/Sharon_Lee_and_Steve_Miller/Agent_of_Change.txt
#   inflating: BaenBooksCorpus2/Sharon_Lee_and_Steve_Miller/Fledgling.txt
#    creating: BaenBooksCorpus2/Timothy_Zahn/
#   inflating: BaenBooksCorpus2/Timothy_Zahn/Cobra.txt
#    creating: BaenBooksCorpus2/Tom_Kratman/
#   inflating: BaenBooksCorpus2/Tom_Kratman/A_Desert_Called_Peace.txt
#   inflating: BaenBooksCorpus2/Tom_Kratman/A_State_of_Disobedience.txt
#   inflating: BaenBooksCorpus2/Tom_Kratman/Caliphate.txt
#   inflating: BaenBooksCorpus2/Tom_Kratman/Training_for_War.txt

# %% [markdown]
# Now we are simply going to get a list of all the text files and print the resulting list of files to make sure it worked.

# %%
files = glob.glob("/content/BaenBooksCorpus2/*/*.txt")
print(files)
# Out:
# ['/content/BaenBooksCorpus2/Ellen_Guon/Bedlam_Boyz.txt', '/content/BaenBooksCorpus2/Ryk_Spoor/Phoenix_Rising.txt', '/content/BaenBooksCorpus2/Ryk_Spoor/Grand_Central_Arena.txt', '/content/BaenBooksCorpus2/Ryk_Spoor/Boundary.txt', '/content/BaenBooksCorpus2/Ryk_Spoor/Digital_Knight.txt', '/content/BaenBooksCorpus2/Charles_Gannon/Fire_with_Fire.txt', '/content/BaenBooksCorpus2/John_Joseph_Adams/Selections_from_The_Improbable_Adventures_of_Sherlock_Holmes.txt', '/content/BaenBooksCorpus2/John_Joseph_Adams/Selections_from_By_Blood_We_Live.txt', '/content/BaenBooksCorpus2/John_Joseph_Adams/Selections_from_Brave_New_Worlds_ Dystopian_Stories.txt', '/content/BaenBooksCorpus2/John_Joseph_Adams/Selections_From_The_Living_Dead_2.txt', '/content/BaenBooksCorpus2/Michael_Williamson/Freehold.txt', '/content/BaenBooksCorpus2/David_Drake/Starliner.txt', '/content/BaenBooksCorpus2/David_Drake/In_the_Heart_of_Darkness.txt', '/content/BaenBooksCorpus2/David_Drake/The_Tank_Lords.txt', '/content/BaenBooksCorpus2/David_Drake/Redliners.txt', '/content/BaenBooksCorpus2/David_Drake/With_the_Lightnings.txt', '/content/BaenBooksCorpus2/David_Drake/Old_Nathan.txt', '/content/BaenBooksCorpus2/David_Drake/The_Sea_Hag.txt', '/content/BaenBooksCorpus2/David_Drake/Seas_of_Venus.txt', '/content/BaenBooksCorpus2/David_Drake/Northworld_Trilogy.txt', '/content/BaenBooksCorpus2/Rosemary_Edgehill/The_Warslayer.txt', '/content/BaenBooksCorpus2/Timothy_Zahn/Cobra.txt', '/content/BaenBooksCorpus2/Marc_Stiegler/EarthWeb.txt', '/content/BaenBooksCorpus2/John_Ringo/A_Hymn_Before_Battle.txt', '/content/BaenBooksCorpus2/John_Ringo/Gust_Front.txt', '/content/BaenBooksCorpus2/John_Ringo/Emerald_Sea.txt', '/content/BaenBooksCorpus2/John_Ringo/There_Will_Be_Dragons.txt', '/content/BaenBooksCorpus2/Sharon_Lee_and_Steve_Miller/Agent_of_Change.txt', '/content/BaenBooksCorpus2/Sharon_Lee_and_Steve_Miller/Fledgling.txt', '/content/BaenBooksCorpus2/Larry_Correia/Monster_Hunter_International.txt', '/content/BaenBooksCorpus2/Scott_Gier/Genellan-Planetfall.txt', '/content/BaenBooksCorpus2/Dave_Freer/The_Forlorn.txt', '/content/BaenBooksCorpus2/Tom_Kratman/A_State_of_Disobedience.txt', '/content/BaenBooksCorpus2/Tom_Kratman/A_Desert_Called_Peace.txt', '/content/BaenBooksCorpus2/Tom_Kratman/Training_for_War.txt', '/content/BaenBooksCorpus2/Tom_Kratman/Caliphate.txt', '/content/BaenBooksCorpus2/Eric_Flint/1632.txt', '/content/BaenBooksCorpus2/Eric_Flint/In_the_Heart_of_Darkness.txt', '/content/BaenBooksCorpus2/Eric_Flint/The_Course_of_Empire.txt', '/content/BaenBooksCorpus2/Eric_Flint/Images_From_the_Grantville_Gazette.txt', '/content/BaenBooksCorpus2/Eric_Flint/Boundary.txt', '/content/BaenBooksCorpus2/Eric_Flint/The_Philosophical_Strangler.txt', '/content/BaenBooksCorpus2/Eric_Flint/Prime_Palaver.txt', '/content/BaenBooksCorpus2/Eric_Flint/The_Creatures_of_Man.txt', '/content/BaenBooksCorpus2/David_Weber/Oath_of_Swords.txt', '/content/BaenBooksCorpus2/David_Weber/The_Honor_of_the_Queen.txt', '/content/BaenBooksCorpus2/David_Weber/On_Basilisk_Station.txt', '/content/BaenBooksCorpus2/Andre_Norton/Time_Traders.txt', '/content/BaenBooksCorpus2/Andre_Norton/Star_Soldiers.txt']

# %% [markdown]
# This next bit of code is essential. It will go through each file, count the word frequence of the keywords and tabulate all of that in a dataframe.

# %%
# Set up the dictionary 
dd ={
     "Author":[],
     "Path":[]
}

# a list of supposedly the most common 100 words
fwords = ["the","at","there","some","my","of","be","use","her","than","and","this","an","would","first","a","have","each","make","water","to","from","which","like","been","in","or","she","him","call","is","one","do","into","who","you","had","how","time","oil","that","by","their","has","its","it","word","if","look","now","he","but","will","two","find","was","not","up","more","long","for","what","other","write","down","on","all","about","go","day","are","were","out","see","did","as","we","many","number","get","with","when","then","no","come","his","your","them","way","made","they","can","these","could","may","I","said","so","people","part"]

# make an empty list for each word as a placeholder
for fw in fwords:
  dd[fw] = []

# just in case
files = glob.glob("/content/BaenBooksCorpus2/*/*.txt")


for file in files:
  # print current file to keep an eye on progress
  print(file)

  # get the author and filename from the path and add to dd
  dd['Author'].append(os.path.dirname(file).split("/")[-1])
  dd['Path'].append(os.path.basename(file))

  # read in the book's text
  with open(file,errors="surrogateescape") as f:
    text = f.read()

  # blobify and convert all words to lowercase
  blob = TextBlob(text)
  word_list = []
  for w in blob.words:
    word_list.append(w.lower())
  
  # get the frequency (per 10,000) for each frequent word
  for word in fwords:
    fr = (word_list.count(word) / len(word_list)) * 10000
    dd[word].append(fr)

df = pd.DataFrame(dd)
# Out:
# /content/BaenBooksCorpus2/Ellen_Guon/Bedlam_Boyz.txt
# /content/BaenBooksCorpus2/Ryk_Spoor/Phoenix_Rising.txt
# /content/BaenBooksCorpus2/Ryk_Spoor/Grand_Central_Arena.txt
# /content/BaenBooksCorpus2/Ryk_Spoor/Boundary.txt
# /content/BaenBooksCorpus2/Ryk_Spoor/Digital_Knight.txt
# /content/BaenBooksCorpus2/Charles_Gannon/Fire_with_Fire.txt
# /content/BaenBooksCorpus2/John_Joseph_Adams/Selections_from_The_Improbable_Adventures_of_Sherlock_Holmes.txt
# /content/BaenBooksCorpus2/John_Joseph_Adams/Selections_from_By_Blood_We_Live.txt
# /content/BaenBooksCorpus2/John_Joseph_Adams/Selections_from_Brave_New_Worlds_ Dystopian_Stories.txt
# /content/BaenBooksCorpus2/John_Joseph_Adams/Selections_From_The_Living_Dead_2.txt
# /content/BaenBooksCorpus2/Michael_Williamson/Freehold.txt
# /content/BaenBooksCorpus2/David_Drake/Starliner.txt
# /content/BaenBooksCorpus2/David_Drake/In_the_Heart_of_Darkness.txt
# /content/BaenBooksCorpus2/David_Drake/The_Tank_Lords.txt
# /content/BaenBooksCorpus2/David_Drake/Redliners.txt
# /content/BaenBooksCorpus2/David_Drake/With_the_Lightnings.txt
# /content/BaenBooksCorpus2/David_Drake/Old_Nathan.txt
# /content/BaenBooksCorpus2/David_Drake/The_Sea_Hag.txt
# /content/BaenBooksCorpus2/David_Drake/Seas_of_Venus.txt
# /content/BaenBooksCorpus2/David_Drake/Northworld_Trilogy.txt
# /content/BaenBooksCorpus2/Rosemary_Edgehill/The_Warslayer.txt
# /content/BaenBooksCorpus2/Timothy_Zahn/Cobra.txt
# /content/BaenBooksCorpus2/Marc_Stiegler/EarthWeb.txt
# /content/BaenBooksCorpus2/John_Ringo/A_Hymn_Before_Battle.txt
# /content/BaenBooksCorpus2/John_Ringo/Gust_Front.txt
# /content/BaenBooksCorpus2/John_Ringo/Emerald_Sea.txt
# /content/BaenBooksCorpus2/John_Ringo/There_Will_Be_Dragons.txt
# /content/BaenBooksCorpus2/Sharon_Lee_and_Steve_Miller/Agent_of_Change.txt
# /content/BaenBooksCorpus2/Sharon_Lee_and_Steve_Miller/Fledgling.txt
# /content/BaenBooksCorpus2/Larry_Correia/Monster_Hunter_International.txt
# /content/BaenBooksCorpus2/Scott_Gier/Genellan-Planetfall.txt
# /content/BaenBooksCorpus2/Dave_Freer/The_Forlorn.txt
# /content/BaenBooksCorpus2/Tom_Kratman/A_State_of_Disobedience.txt
# /content/BaenBooksCorpus2/Tom_Kratman/A_Desert_Called_Peace.txt
# /content/BaenBooksCorpus2/Tom_Kratman/Training_for_War.txt
# /content/BaenBooksCorpus2/Tom_Kratman/Caliphate.txt
# /content/BaenBooksCorpus2/Eric_Flint/1632.txt
# /content/BaenBooksCorpus2/Eric_Flint/In_the_Heart_of_Darkness.txt
# /content/BaenBooksCorpus2/Eric_Flint/The_Course_of_Empire.txt
# /content/BaenBooksCorpus2/Eric_Flint/Images_From_the_Grantville_Gazette.txt
# /content/BaenBooksCorpus2/Eric_Flint/Boundary.txt
# /content/BaenBooksCorpus2/Eric_Flint/The_Philosophical_Strangler.txt
# /content/BaenBooksCorpus2/Eric_Flint/Prime_Palaver.txt
# /content/BaenBooksCorpus2/Eric_Flint/The_Creatures_of_Man.txt
# /content/BaenBooksCorpus2/David_Weber/Oath_of_Swords.txt
# /content/BaenBooksCorpus2/David_Weber/The_Honor_of_the_Queen.txt
# /content/BaenBooksCorpus2/David_Weber/On_Basilisk_Station.txt
# /content/BaenBooksCorpus2/Andre_Norton/Time_Traders.txt
# /content/BaenBooksCorpus2/Andre_Norton/Star_Soldiers.txt

# %% [markdown]
# Now we are going to generate a scatterplot from that dataframe. But first we are going to print the dataframe in a table to make sure it is processing the information from the text files correctly.

# %%
df
# Out:
#                          Author  \
# 0                    Ellen_Guon
# 1                     Ryk_Spoor
# 2                     Ryk_Spoor
# 3                     Ryk_Spoor
# 4                     Ryk_Spoor
# 5                Charles_Gannon
# 6             John_Joseph_Adams
# 7             John_Joseph_Adams
# 8             John_Joseph_Adams
# 9             John_Joseph_Adams
# 10           Michael_Williamson
# 11                  David_Drake
# 12                  David_Drake
# 13                  David_Drake
# 14                  David_Drake
# 15                  David_Drake
# 16                  David_Drake
# 17                  David_Drake
# 18                  David_Drake
# 19                  David_Drake
# 20            Rosemary_Edgehill
# 21                 Timothy_Zahn
# 22                Marc_Stiegler
# 23                   John_Ringo
# 24                   John_Ringo
# 25                   John_Ringo
# 26                   John_Ringo
# 27  Sharon_Lee_and_Steve_Miller
# 28  Sharon_Lee_and_Steve_Miller
# 29                Larry_Correia
# 30                   Scott_Gier
# 31                   Dave_Freer
# 32                  Tom_Kratman
# 33                  Tom_Kratman
# 34                  Tom_Kratman
# 35                  Tom_Kratman
# 36                   Eric_Flint
# 37                   Eric_Flint
# 38                   Eric_Flint
# 39                   Eric_Flint
# 40                   Eric_Flint
# 41                   Eric_Flint
# 42                   Eric_Flint
# 43                   Eric_Flint
# 44                  David_Weber
# 45                  David_Weber
# 46                  David_Weber
# 47                 Andre_Norton
# 48                 Andre_Norton
#
#                                                  Path         the         at  \
# 0                                     Bedlam_Boyz.txt  518.988468  79.335817
# 1                                  Phoenix_Rising.txt  520.357617  49.335636
# 2                             Grand_Central_Arena.txt  444.965928  52.630985
# 3                                        Boundary.txt  486.140584  62.864721
# 4                                  Digital_Knight.txt  425.102442  60.988816
# 5                                  Fire_with_Fire.txt  507.991751  58.831179
# 6   Selections_from_The_Improbable_Adventures_of_S...  546.473610  52.014776
# 7                Selections_from_By_Blood_We_Live.txt  587.003468  56.933447
# 8   Selections_from_Brave_New_Worlds_ Dystopian_St...  500.032951  58.488204
# 9               Selections_From_The_Living_Dead_2.txt  596.556254  54.424322
# 10                                       Freehold.txt  440.545452  49.170064
# 11                                      Starliner.txt  706.592950  57.950635
# 12                       In_the_Heart_of_Darkness.txt  727.555100  59.223921
# 13                                 The_Tank_Lords.txt  838.770504  52.563953
# 14                                      Redliners.txt  775.200687  49.270812
# 15                            With_the_Lightnings.txt  754.660771  59.112219
# 16                                     Old_Nathan.txt  773.563372  41.798212
# 17                                    The_Sea_Hag.txt  774.306824  54.794198
# 18                                  Seas_of_Venus.txt  840.780708  52.592621
# 19                             Northworld_Trilogy.txt  746.667193  53.798217
#
#            so     people      part
# 0   21.486784  11.188384  1.398548
# 1   33.134880  11.667211  6.200289
# 2   35.595018  14.779548  5.189765
# 3   35.543767  13.129973  6.034483
# 4   40.110542  17.759527  5.717701
# 5   42.296522   2.724813  4.644567
# 6   32.907308   3.609189  3.396883
# 7   35.992409   6.762210  3.708309
# 8   31.138790  19.276394  4.118888
# 9   27.446749   8.679741  2.580464
# 10  18.273347  11.910761  2.646836
# 11  19.068316  11.504906  1.597904
# 12  27.940018   3.938354  2.898034
# 13  19.523754   4.422047  2.920220
# 14  17.970517  10.466345  2.172260
# 15  21.089107   8.075011  3.527918
# 16  24.308180   1.630427  2.075089
# 17  23.803071   4.124294  2.003229
# 18  18.543769   4.207410  3.584090
# 19  19.286898   3.115879  2.445374
# 20  25.843146   9.191077  3.243910
# 21  22.485034   9.928457  4.185526
# 22  26.372246  17.267542  3.348857
# 23  20.040080   3.450124  2.716055
# 24  24.417804   5.281865  2.078111
# 25  26.460144   8.986464  2.246616
# 26  31.541667  14.007481  3.029987
# 27  27.123125   6.723800  1.367553
# 28  32.099918   5.169337  2.334540
# 29  27.279282  10.185610  2.067376
# 30  11.715207   4.031039  0.881790
# 31  23.383508   7.005586  3.692133
# 32  35.342589  17.866557  4.002890
# 33  27.901150  12.323686  4.758651
# 34  32.719199  10.906400  7.400771
# 35  28.074534  11.594203  4.389234
# 36  29.139625   9.330935  4.013866
# 37  27.940018   3.938354  2.898034
# 38  34.265484   2.504454  3.472084
# 39  28.821449  15.565072  6.106870
# 40  35.543767  13.129973  6.034483
# 41  37.588808   3.240414  4.131528
# 42  34.962175  33.530975  3.884686
# 43  29.429039   8.904495  2.968165
# 44  28.169595   6.733220  3.229197
# 45  17.966690  14.277712  1.981118
# 46  19.548658  11.459558  2.621468
# 47  25.395012   7.101341  3.550670
# 48  23.292755   3.134193  2.065718
#
# [49 rows x 102 columns]

# %%
df = pd.DataFrame(dd)
fig = px.scatter(df, x="there", y="their", color="Author",hover_name="Path",symbol="Author")
fig.update_traces(marker=dict(size=20,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b7a47372-c95c-40a1-83c9-28e0d4b6a195" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7a47372-c95c-40a1-83c9-28e0d4b6a195")) {                    Plotly.newPlot(                        "b7a47372-c95c-40a1-83c9-28e0d4b6a195",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Author=Ellen_Guon<br>there=%{x}<br>their=%{y}<extra></extra>","hovertext":["Bedlam_Boyz.txt"],"legendgroup":"Ellen_Guon","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":20},"mode":"markers","name":"Ellen_Guon","orientation":"v","showlegend":true,"x":[33.18373107192351],"xaxis":"x","y":[9.281273441572477],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Author=Ryk_Spoor<br>there=%{x}<br>their=%{y}<extra></extra>","hovertext":["Phoenix_Rising.txt","Grand_Central_Arena.txt","Boundary.txt","Digital_Knight.txt"],"legendgroup":"Ryk_Spoor","marker":{"color":"#EF553B","symbol":"diamond","line":{"color":"DarkSlateGrey","width":2},"size":20},"mode":"markers","name":"Ryk_Spoor","orientation":"v","showlegend":true,"x":[31.401465401718745,32.77449343381922,38.726790450928384,35.34579099202121],"xaxis":"x","y":[16.93412359243431,19.743670743264587,17.838196286472147,13.341303462674672],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Author=Charles_Gannon<br>there=%{x}<br>their=%{y}<extra></extra>","hovertext":["Fire_with_Fire.txt"],"legendgroup":"Charles_Gannon","marker":{"color":"#00cc96","symbol":"square","line":{"color":"DarkSlateGrey","width":2},"size":20},"mode":"markers","name":"Charles_Gannon","orientation":"v","showlegend":true,"x":[24.027892171737502],"xaxis":"x","y":[22.108137900284248],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Author=John_Joseph_Adams<br>there=%{x}<br>their=%{y}<extra></extra>","hovertext":["Selections_from_The_Improbable_Adventures_of_Sherlock_Holmes.txt","Selections_from_By_Blood_We_Live.txt","Selections_from_Brave_New_Worlds_ Dystopian_Stories.txt","Selections_From_The_Living_Dead_2.txt"],"legendgroup":"John_Joseph_Adams","marker":{"color":"#ab63fa","symbol":"x","line":{"color":"DarkSlateGrey","width":2},"size":20},"mode":"markers","name":"John_Joseph_Adams","orientation":"v","showlegend":true,"x":[38.639548214513184,32.065964269354104,30.150257018584423,29.323449375996997],"xaxis":"x","y":[13.58753343807057,18.323408153916628,20.429682351390536,31.200150136060806],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Author=Michael_Williamson<br>there=%{x}<br>their=%{y}<extra></extra>","hovertext":["Freehold.txt"],"legendgroup":"Michael_Williamson","marker":{"color":"#FFA15A","symbol":"cross","line":{"color":"DarkSlateGrey","width":2},"size":20},"mode":"markers","name":"Michael_Williamson","orientation":"v","showlegend":true,"x":[35.5286799924667],"xaxis":"x","y":[19.494963376955223],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Author=David_Drake<br>there=%{x}<br>their=%{y}<extra></extra>","hovertext":["Starliner.txt","In_the_Heart_of_Darkness.txt","The_Tank_Lords.txt","Redliners.txt","With_the_Lightnings.txt","Old_Nathan.txt","The_Sea_Hag.txt","Seas_of_Venus.txt","Northworld_Trilogy.txt"],"legendgroup":"David_Drake","marker":{"color":"#19d3f3","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":20},"mode":"markers","name":"David_Drake","orientation":"v","showlegend":true,"x":[31.531963397356005,24.150281629438076,31.371501994092814,36.63220672018326,31.437665616131206,35.72116738553663,32.169496718239984,33.970937706961706,30.409402855565197],"xaxis":"x","y":[30.999328880508774,56.02865338029634,33.79111252023295,21.32764596107704 ...

# %% [markdown]
# This next part is not crucial to the comparison, but it does allow you to upload the graph and dataframe above to Plotly. This makes it possible to obtain a reactive embed code to embed the graph on a site.
#
# To do this you will need a free Plotly account. You have to provide your Plotly usernmae and the API key associated with your account. Once it has processed your credentials, you will need to assign the file a name and it should appear under "My Files" on your Plotly account.
#
# *Note: I have starred-out my own username and API key for this demonstration. For information on this method, check out [How To Create a Plotly Visualization And Embed It On Websites](https://https://towardsdatascience.com/how-to-create-a-plotly-visualization-and-embed-it-on-websites-517c1a78568b) on The Medium.

# %%
# !pip install chart_studio
import chart_studio
username = '*******' # your username
api_key = '********************' # your api key - go to profile > settings > regenerate key
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
import chart_studio.plotly as py
py.plot(fig, filename = 'baen-books-theretheir-graph', auto_open=True)
